# %%
import pandas as pd
import numpy as np
import csv
from sklearn import preprocessing

# %%
df = pd.read_csv('voice.csv')
df
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %%
df.dropna()
df
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %%
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(df[["meanfreq","sd","median","Q25","Q75","IQR","skew","kurt","sp.ent","sfm","mode","centroid","meanfun","minfun","maxfun","meandom","mindom","maxdom","dfrange","modindx"]])
df2 = pd.DataFrame(x_scaled, columns= ["meanfreq","sd","median","Q25","Q75","IQR","skew","kurt","sp.ent","sfm","mode","centroid","meanfun","minfun","maxfun","meandom","mindom","maxdom","dfrange","modindx"])
df2
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0     0.096419  0.473409  0.084125  0.060063  0.204956  0.254828  0.367853
# 1     0.125828  0.505075  0.116900  0.077635  0.215683  0.246961  0.644279
# 2     0.179222  0.675536  0.102873  0.034284  0.385912  0.457148  0.885255
# 3     0.528261  0.554611  0.587559  0.389906  0.715802  0.407358  0.031549
# 4     0.452195  0.627209  0.454272  0.317627  0.707515  0.474474  0.027742
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163  0.436911  0.684871  0.570361  0.198513  0.686256  0.577704  0.046854
# 3164  0.362946  0.731172  0.262871  0.171937  0.702595  0.621185  0.015961
# 3165  0.484949  0.799042  0.690337  0.134329  0.786967  0.742124  0.050161
# 3166  0.492516  0.745692  0.695311  0.175136  0.767804  0.681107  0.041908
# 3167  0.595700  0.768964  0.687590  0.282629  0.901780  0.699289  0.045203
#
# ...

# %%
df3 = df
df3.update(df2)
df3
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0     0.096419  0.473409  0.084125  0.060063  0.204956  0.254828  0.367853
# 1     0.125828  0.505075  0.116900  0.077635  0.215683  0.246961  0.644279
# 2     0.179222  0.675536  0.102873  0.034284  0.385912  0.457148  0.885255
# 3     0.528261  0.554611  0.587559  0.389906  0.715802  0.407358  0.031549
# 4     0.452195  0.627209  0.454272  0.317627  0.707515  0.474474  0.027742
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163  0.436911  0.684871  0.570361  0.198513  0.686256  0.577704  0.046854
# 3164  0.362946  0.731172  0.262871  0.171937  0.702595  0.621185  0.015961
# 3165  0.484949  0.799042  0.690337  0.134329  0.786967  0.742124  0.050161
# 3166  0.492516  0.745692  0.695311  0.175136  0.767804  0.681107  0.041908
# 3167  0.595700  0.768964  0.687590  0.282629  0.901780  0.699289  0.045203
#
# ...

# %%
df3.to_csv('voice_norm.csv', index=False)

# %%
import matplotlib.pyplot as plt

# %%
df3.hist('kurt')
# Out:
# array([[<AxesSubplot:title={'center':'kurt'}>]], dtype=object)

# %%
df3['kurt'].std()
# Out:
# 0.1031924100980849

# %%
df3['kurt'].mean()
# Out:
# 0.026385340688467963

# %%
df3['meanfun'].std()
# Out:
# 0.17742762901254777

# %%
df3['meanfun'].hist()
# Out:
# <AxesSubplot:>

# %%
df3['meanfun'].mean()
# Out:
# 0.47916124357445544

# %%
import seaborn as sns
# %matplotlib inline

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10)) 

# calculate the correlation matrix
corr = df.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:>

# %%
cor_matrix = df.corr().abs()
print(cor_matrix)
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000  0.739039  0.925445  0.911416  0.740997  0.627605
# sd        0.739039  1.000000  0.562603  0.846931  0.161076  0.874660
# median    0.925445  0.562603  1.000000  0.774922  0.731849  0.477352
# Q25       0.911416  0.846931  0.774922  1.000000  0.477140  0.874189
# Q75       0.740997  0.161076  0.731849  0.477140  1.000000  0.009636
# IQR       0.627605  0.874660  0.477352  0.874189  0.009636  1.000000
# skew      0.322327  0.314597  0.257407  0.319475  0.206339  0.249497
# kurt      0.316036  0.346241  0.243382  0.350182  0.148881  0.316185
# sp.ent    0.601203  0.716620  0.502005  0.648126  0.174905  0.640813
# sfm       0.784332  0.838086  0.661690  0.766875  0.378198  0.663601
# mode      0.687715  0.529150  0.677433  0.591277  0.486857  0.403764
# centroid  1.000000  0.739039  0.925445  0.911416  0.740997  0.627605
# meanfun   0.460844  0.466281  0.414909  0.545035  0.155091  0.534462
# ...

# %%
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
print(upper_tri)
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq       NaN  0.739039  0.925445  0.911416  0.740997  0.627605
# sd             NaN       NaN  0.562603  0.846931  0.161076  0.874660
# median         NaN       NaN       NaN  0.774922  0.731849  0.477352
# Q25            NaN       NaN       NaN       NaN  0.477140  0.874189
# Q75            NaN       NaN       NaN       NaN       NaN  0.009636
# IQR            NaN       NaN       NaN       NaN       NaN       NaN
# skew           NaN       NaN       NaN       NaN       NaN       NaN
# kurt           NaN       NaN       NaN       NaN       NaN       NaN
# sp.ent         NaN       NaN       NaN       NaN       NaN       NaN
# sfm            NaN       NaN       NaN       NaN       NaN       NaN
# mode           NaN       NaN       NaN       NaN       NaN       NaN
# centroid       NaN       NaN       NaN       NaN       NaN       NaN
# meanfun        NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.9)]
print(); print(to_drop)
# Out:
# ['median', 'Q25', 'kurt', 'centroid', 'dfrange']

# %%
df1 = df.drop(df.columns[to_drop], axis=1)
df1
# Out:
# /Users/estrella/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5055: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df1 = df.drop(df.columns[to_drop], axis=1)
#       2 df1
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5055, in Index.__getitem__(self, key)
#    5048 if com.is_bool_indexer(key):
#    5049     # if we have list[bools, length=1e5] then doing this check+convert
#    5050     #  takes 166 µs + 2.1 ms and cuts the ndarray.__getitem__
# ...
