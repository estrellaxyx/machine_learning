# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'diabetes.csv',decimal=",")
df
# Out:
#      patient_number  cholesterol  glucose  hdl_chol  chol_hdl_ratio  age  \
# 0                 1          193       77        49             3.9   19
# 1                 2          146       79        41             3.6   19
# 2                 3          217       75        54             4.0   20
# 3                 4          226       97        70             3.2   20
# 4                 5          164       91        67             2.4   20
# ..              ...          ...      ...       ...             ...  ...
# 385             386          227      105        44             5.2   83
# 386             387          226      279        52             4.3   84
# 387             388          301       90       118             2.6   89
# 388             389          232      184       114             2.0   91
# 389             390          165       94        69             2.4   92
#
#      gender  height  weight   bmi  systolic_bp  diastolic_bp  waist  hip  \
# ...

# %%
df.dropna()
df
# Out:
#      patient_number  cholesterol  glucose  hdl_chol  chol_hdl_ratio  age  \
# 0                 1          193       77        49             3.9   19
# 1                 2          146       79        41             3.6   19
# 2                 3          217       75        54             4.0   20
# 3                 4          226       97        70             3.2   20
# 4                 5          164       91        67             2.4   20
# ..              ...          ...      ...       ...             ...  ...
# 385             386          227      105        44             5.2   83
# 386             387          226      279        52             4.3   84
# 387             388          301       90       118             2.6   89
# 388             389          232      184       114             2.0   91
# 389             390          165       94        69             2.4   92
#
#      gender  height  weight   bmi  systolic_bp  diastolic_bp  waist  hip  \
# ...

# %%
df2 = df.drop(['height', 'chol_hdl_ratio', 'weight','height','hip', 'waist','patient_number'], axis=1)
df2
# Out:
#      cholesterol  glucose  hdl_chol  age  gender   bmi  systolic_bp  \
# 0            193       77        49   19  female  22.5          118
# 1            146       79        41   19  female  26.4          108
# 2            217       75        54   20  female  29.3          110
# 3            226       97        70   20  female  19.6          122
# 4            164       91        67   20  female  20.2          122
# ..           ...      ...       ...  ...     ...   ...          ...
# 385          227      105        44   83  female  25.2          150
# 386          226      279        52   84  female  37.5          144
# 387          301       90       118   89  female  21.7          218
# 388          232      184       114   91  female  24.0          170
# 389          165       94        69   92  female  39.7          160
#
#      diastolic_bp  waist_hip_ratio     diabetes
# 0              70             0.84  No diabetes
# 1              58             0.83  No diabetes
# ...

# %%
df2['diabetes'].describe()
# Out:
# count             390
# unique              2
# top       No diabetes
# freq              330
# Name: diabetes, dtype: object

# %%
df2['cholesterol'].describe()
# Out:
# count    390.000000
# mean     207.230769
# std       44.666005
# min       78.000000
# 25%      179.000000
# 50%      203.000000
# 75%      229.000000
# max      443.000000
# Name: cholesterol, dtype: float64

# %%
df2.to_csv('diabetes2.csv', index=False)
